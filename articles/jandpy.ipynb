# %% [markdown]
# # Calling J inside Python

# %% [markdown]
# Why would you call j from python? for me; j is helping me understan how things work, let's give an example:
# in python; to get linear regression, you will search for a library - let's say statsmodel or scipy to call linear regression functions, here you didn't know how it works.
#
# In j - for same example - you will find that you can get linear regression through 2 verbs(functions) those represent same mathematical formulas calculating linear regression.
# another reason you would like to use j inside python is the speed you can get from j, as array language are famous for the speed their interpretters can reach, this is to be compared with python scripts not with numpy or c functions
#
# Calling J from inside Python is seamless, as easy as importing one python script 'jbase.py'

# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, 'C:/Users/e120294/Desktop/Sync/jcb/')

import jbase as jb
import numpy as np
from matplotlib import pylab as pl
jb.init()

# %%
jb.do ('a=:i. 2 3 4')
a = jb.get ('a')

# %%
pl.plot (np.sin(a)[1])

# %%
jb.do("load 'trig numeric'")
# Out:
# 0

# %%
jb.do('x=: (sin,.cos) steps 1 10 100')
# Out:
# 0

# %%
x=jb.get('x')

# %%
pl.plot(x)
